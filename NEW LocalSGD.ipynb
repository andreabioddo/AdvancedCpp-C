# %% [markdown]
# <a href="https://colab.research.google.com/github/andreabioddo/AdvancedCpp-C/blob/main/NEW%20LocalSGD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# ## Imports

# %%
import torch
import argparse
from torch.optim.optimizer import Optimizer, required
import torch
import torchvision
import torchvision.transforms as transforms
import random
import numpy as np
import json
from PIL import Image
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, SequentialLR, LinearLR, LambdaLR
import matplotlib.pyplot as plt
import copy
import time
from sklearn.model_selection import train_test_split
from torch.amp import GradScaler, autocast
import os
from google.colab import drive
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.optim.lr_scheduler")
drive.mount('/content/drive')
if not os.path.exists('/content/drive/MyDrive'):
    raise RuntimeError("Google Drive not mounted correctly!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Model

# %%
class LeNet5(nn.Module):
    def __init__(self):
        super(LeNet5, self).__init__()

        self.conv1 = nn.Conv2d(3, 64, kernel_size=5)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=5)

        # Layer fully connected
        self.fc1 = nn.Linear(64 * 5 * 5, 384)
        self.fc2 = nn.Linear(384, 192)
        self.fc3 = nn.Linear(192, 100)

    def forward(self, x):
        # Layer convolutivi con ReLU e max-pooling
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # Flatten per i layer fully connected
        x = torch.flatten(x, 1)

        # Layer fully connected con ReLU
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))

        x = self.fc3(x)
        x = F.log_softmax(x, dim=1)

        return x

# %% [markdown]
# ## Early stopping

# %%
# Early Stopping Class
class EarlyStopping:
    def __init__(self, patience=10, delta=0, path='/content/drive/MyDrive/Early2checkpoint.pt', verbose=False):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = float('inf')
        self.delta = delta
        self.path = path
        self.verbose = verbose

    def __call__(self, val_loss, model):
        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f"EarlyStopping counter: {self.counter} out of {self.patience}")
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model, optimizer=None):
        if self.verbose:
            print(f"Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model ...")
        checkpoint = {
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict() if optimizer else None,
            'val_loss_min': val_loss
        }
        torch.save(checkpoint, self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# ## Function to get train, test and val dataset

# %%
def get_dataset(batch_size):
    batch_size=batch_size
    print("batch_size", batch_size)
    # Define the transform to only convert the images to tensors (without normalization yet)
    transform = transforms.Compose([
        transforms.ToTensor(),
    ])

    # Load the CIFAR-100 training dataset
    train_dataset = torchvision.datasets.CIFAR100(
        root='./data',
        train=True,
        download=True,
        transform=transform
    )


    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size, shuffle=False, num_workers=2)

    # Initialize sums for calculating mean and std
    mean = torch.zeros(3)
    std = torch.zeros(3)

    for images, _ in train_loader:
        # Compute mean and std for each channel
        mean += images.mean(dim=[0, 2, 3])
        std += images.std(dim=[0, 2, 3])

    mean /= len(train_loader)
    std /= len(train_loader)

    print("Mean: ", mean)
    print("Std: ", std)

    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[mean[0].item(), mean[1].item(), mean[2].item()],
                            std=[std[0].item(), std[1].item(), std[2].item()])
    ])

    transform_test = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.ToTensor(),
        transforms.Normalize(mean=[mean[0].item(), mean[1].item(), mean[2].item()],
                            std=[std[0].item(), std[1].item(), std[2].item()])
    ])

    # Load CIFAR-100 dataset
    start_time = time.time()
    train_dataset = torchvision.datasets.CIFAR100(
        root='./data',
        train=True,
        download=True,
        transform=transform_train
    )
    test_dataset = torchvision.datasets.CIFAR100(
        root='./data',
        train=False,
        download=True,
        transform=transform_test
    )
    print(f"Dataset loading time: {time.time() - start_time:.2f} seconds")

    # Split training and validation sets
    train_size = int(0.8 * len(train_dataset))
    val_size = len(train_dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

    # Data loaders
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True
    )

    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )

    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )

    # Debugging: Check DataLoader outputs
    for i, (inputs, labels) in enumerate(train_loader):
        print(f"Batch {i}: inputs shape: {inputs.shape}, labels shape: {labels.shape}")
        if i == 10:  # Test first 10 batches
            break
    print(f"Data loading for 10 batches completed.")
    print(f"Training dataset size: {len(train_dataset)}")
    print(f"Validation dataset size: {len(val_dataset)}")
    print(f"Test dataset size: {len(test_dataset)}")

    return train_loader, val_loader, test_loader

# %% [markdown]
# # LocalSGD

# %%
def split_cifar100(dataset, num_workers):
    indices = np.random.permutation(len(dataset))
    splits = np.array_split(indices, num_workers)
    return [torch.utils.data.Subset(dataset, split) for split in splits]


def local_sgd(train_dataset, val_loader, test_loader, device, num_workers, local_steps, num_epochs, batch_size, hyperparams):
    dataset_size = len(train_dataset)
    datasets = split_cifar100(train_dataset, num_workers)
    workers = [
        torch.utils.data.DataLoader(
            datasets[i],
            batch_size=batch_size,
            shuffle=True,
            num_workers=0,
            pin_memory=True,
        )
        for i in range(num_workers)
    ]

    total_iterations = (num_epochs * (dataset_size // batch_size)) // (num_workers * local_steps)
    iterations_per_epoch = total_iterations // num_epochs

    global_model = LeNet5().to(device)
    local_models = [copy.deepcopy(global_model).to(device) for _ in range(num_workers)]
    local_optimizers = [
        optim.SGD(
            model.parameters(),
            lr=hyperparams['lr'],
            weight_decay=hyperparams['weight_decay'],
            momentum=hyperparams['momentum'],
        )
        for model in local_models
    ]

    schedulers = [CosineAnnealingLR(opt, T_max=num_epochs) for opt in local_optimizers]
    criterion = nn.CrossEntropyLoss()
    local_weights = [len(datasets[i].indices) / dataset_size for i in range(num_workers)]

    val_losses, val_accuracies = [], []
    train_losses, train_accuracies = [], []
    #best_val_acc = 0.0
    #best_model_state = None

    worker_iters = [iter(workers[i]) for i in range(num_workers)]

    for iteration in range(1, total_iterations + 1):
        # Local training for H steps
        for worker_id in range(num_workers):
            local_models[worker_id].train()
            for _ in range(local_steps):
                try:
                    inputs, labels = next(worker_iters[worker_id])
                except StopIteration:
                    worker_iters[worker_id] = iter(workers[worker_id])
                    inputs, labels = next(worker_iters[worker_id])

                inputs, labels = inputs.to(device), labels.to(device)
                local_optimizers[worker_id].zero_grad()
                outputs = local_models[worker_id](inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                local_optimizers[worker_id].step()

        # Model averaging after H steps
        with torch.no_grad():
            global_state_dict = global_model.state_dict()
            for key in global_state_dict.keys():
                global_state_dict[key] = torch.sum(
                    torch.stack([
                        local_weights[i] * local_models[i].state_dict()[key]
                        for i in range(num_workers)
                    ]),
                    dim=0
                )

            global_model.load_state_dict(global_state_dict)
            # Update local models with averaged weights
            for local_model in local_models:
                local_model.load_state_dict(global_state_dict)

        if iteration % iterations_per_epoch == 0:
            # Global metrics calculation
            global_model.eval()
            global_train_loss, global_correct, global_total = 0.0, 0, 0
            with torch.no_grad():
                # Train on the global model after local updates
                for inputs, labels in workers[0]:
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = global_model(inputs)
                    loss = criterion(outputs, labels)
                    global_train_loss += loss.item()
                    _, predicted = outputs.max(1)
                    global_correct += predicted.eq(labels).sum().item()
                    global_total += labels.size(0)

            global_train_loss /= len(workers[0])
            global_train_acc = global_correct / global_total
            train_losses.append(global_train_loss)
            train_accuracies.append(global_train_acc)


            # Validation
            global_model.eval()
            val_loss, correct, total = 0.0, 0, 0
            with torch.no_grad():
                for inputs, labels in val_loader:
                    inputs, labels = inputs.to(device), labels.to(device)
                    outputs = global_model(inputs)
                    loss = criterion(outputs, labels)
                    val_loss += loss.item()
                    _, predicted = outputs.max(1)
                    correct += predicted.eq(labels).sum().item()
                    total += labels.size(0)

            val_loss /= len(val_loader)
            val_acc = correct / total
            val_losses.append(val_loss)
            val_accuracies.append(val_acc)

            #if val_acc > best_val_acc:
                #best_val_acc = val_acc
                #best_model_state = copy.deepcopy(global_model.state_dict())

            print(f"Iteration {iteration} / {total_iterations} -> {(iteration/total_iterations)*100:.2f}% | Train Loss: {global_train_loss:.4f}, Train Acc: {global_train_acc * 100:.2f}%  | Val Loss: {val_loss:.4f}, Val Acc: {val_acc * 100:.2f}%")

            # Step schedulers after each epoch
            for scheduler in schedulers:
                scheduler.step()

    # Ripristina il miglior modello
    #if best_model_state:
        # global_model.load_state_dict(best_model_state)

    # Valutazione finale sul test set
    global_model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = global_model(inputs)
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().item()
            total += labels.size(0)

    test_acc = correct / total
    print(f"Test Accuracy: {test_acc * 100:.2f}%")

    return train_losses, val_losses, train_accuracies, val_accuracies, test_acc, total_iterations, iterations_per_epoch



# Visualization function
def plot_results(train_losses, val_losses, train_accuracies, val_accuracies, iterations_per_epoch, total_iterations):
    # Dynamic calculation record points
    recorded_iterations = len(train_losses)
    iterations = range(iterations_per_epoch, iterations_per_epoch * recorded_iterations + 1, iterations_per_epoch)

    # Ensure data length is consistent
    assert len(train_losses) == len(iterations), f"Train losses and iterations mismatch: {len(train_losses)} vs {len(iterations)}"
    assert len(val_losses) == len(iterations), f"Validation losses and iterations mismatch: {len(val_losses)} vs {len(iterations)}"

    plt.figure(figsize=(12, 5))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(iterations, train_losses, label="Train Loss")
    plt.plot(iterations, val_losses, label="Validation Loss")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.title("Training and Validation Loss")
    plt.legend()

    # Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(iterations, train_accuracies, label="Train Accuracy")
    plt.plot(iterations, val_accuracies, label="Validation Accuracy")
    plt.xlabel("Iterations")
    plt.ylabel("Accuracy (%)")
    plt.title("Training and Validation Accuracy")
    plt.legend()

    plt.tight_layout()
    plt.show()


if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    num_epochs = 150
    batch_size = 64
    num_workers_list = [2, 4, 8]
    local_steps_list = [4, 8, 16, 32, 64]
    hyperparams = {
        'lr': 0.01,
        'weight_decay': 0.001,
        'momentum': 0.9,
    }

    train_loader, val_loader, test_loader = get_dataset(batch_size)
    train_dataset = train_loader.dataset

    for num_workers in num_workers_list:
        for local_steps in local_steps_list:
            print(f"Running LocalSGD with {num_workers} workers and {local_steps} local steps")
            train_losses, val_losses, train_accuracies, val_accuracies, test_acc, total_iterations, iterations_per_epoch = local_sgd(
                train_dataset=train_dataset,
                val_loader=val_loader,
                test_loader=test_loader,
                device=device,
                num_workers=num_workers,
                local_steps=local_steps,
                num_epochs=num_epochs,
                batch_size=batch_size,
                hyperparams=hyperparams,
            )

            plot_results(train_losses, val_losses, train_accuracies, val_accuracies, iterations_per_epoch, total_iterations)
# Out:
# batch_size 64
# Files already downloaded and verified
# Mean:  tensor([0.5070, 0.4865, 0.4408])
# Std:  tensor([0.2664, 0.2555, 0.2750])
# Files already downloaded and verified
# Files already downloaded and verified
# Dataset loading time: 1.79 seconds
# Batch 0: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 1: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 2: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 3: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 4: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 5: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 6: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 7: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 8: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 9: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Batch 10: inputs shape: torch.Size([64, 3, 32, 32]), labels shape: torch.Size([64])
# Data loading for 10 batches completed.
# Training dataset size: 40000
# Validation dataset size: 10000
# Test dataset size: 10000
# Running LocalSGD with 1 workers and 1 local steps
# Worker 0: Label Distribution - {0: 393, 1: 388, 2: 387, 3: 394, 4: 395, 5: 391, 6: 400, 7: 400, 8: 390, 9: 389, 10: 393, 11: 386, 12: 404, 13: 403, 14: 383, 15: 402, 16: 400, 17: 403, 18: 410, 19: 421, 20: 416, 21: 393, 22: 403, 23: 396, 24: 401, 25: 407, 26: 399, 27: 409, 28: 404, 29: 397, 30: 415, 31: 399, 32: 406, 33: 411, 34: 395, 35: 399, 36: 394, 37: 403, 38: 393, 39: 397, 40: 398, 41: 411, 42: 400, 43: 399, 44: 401, 45: 398, 46: 403, 47: 399, 48: 389, 49: 396, 50: 407, 51: 402, 52: 407, 53: 393, 54: 385, 55: 408, 56: 401, 57: 411, 58: 391, 59: 406, 60: 391, 61: 406, 62: 387, 63: 385, 64: 399, 65: 399, 66: 394, 67: 401, 68: 405, 69: 388, 70: 419, 71: 418, 72: 391, 73: 400, 74: 418, 75: 387, 76: 403, 77: 413, 78: 409, 79: 401, 80: 403, 81: 404, 82: 391, 83: 412, 84: 397, 85: 402, 86: 411, 87: 394, 88: 401, 89: 411, 90: 405, 91: 404, 92: 405, 93: 400, 94: 399, 95: 400, 96: 396, 97: 394, 98: 392, 99: 391}
# Epoch 1/150 | Train Loss: 4.5868, Train Acc: 3.12% | Val Loss: 4.5895, Val Acc: 2.68%
# Epoch 2/150 | Train Loss: 4.4277, Train Acc: 3.12% | Val Loss: 4.4037, Val Acc: 5.03%
# Epoch 3/150 | Train Loss: 4.2463, Train Acc: 4.69% | Val Loss: 4.2043, Val Acc: 6.78%
# Epoch 4/150 | Train Loss: 4.0925, Train Acc: 20.31% | Val Loss: 4.0834, Val Acc: 9.93%
# Epoch 5/150 | Train Loss: 4.0709, Train Acc: 7.81% | Val Loss: 4.0081, Val Acc: 11.00%
# Epoch 6/150 | Train Loss: 3.9656, Train Acc: 10.94% | Val Loss: 3.9239, Val Acc: 13.21%
# Epoch 7/150 | Train Loss: 3.9113, Train Acc: 15.62% | Val Loss: 3.8789, Val Acc: 13.94%
# Epoch 8/150 | Train Loss: 3.7185, Train Acc: 15.62% | Val Loss: 3.8109, Val Acc: 15.89%
# Epoch 9/150 | Train Loss: 3.8038, Train Acc: 15.62% | Val Loss: 3.7910, Val Acc: 15.98%
# Epoch 10/150 | Train Loss: 3.7085, Train Acc: 21.88% | Val Loss: 3.7153, Val Acc: 17.80%
# Epoch 11/150 | Train Loss: 3.4813, Train Acc: 20.31% | Val Loss: 3.6870, Val Acc: 18.91%
# Epoch 12/150 | Train Loss: 3.5232, Train Acc: 23.44% | Val Loss: 3.6372, Val Acc: 19.10%
# Epoch 13/150 | Train Loss: 3.4749, Train Acc: 23.44% | Val Loss: 3.6027, Val Acc: 20.02%
# Epoch 14/150 | Train Loss: 3.4126, Train Acc: 15.62% | Val Loss: 3.5535, Val Acc: 21.14%
# Epoch 15/150 | Train Loss: 3.6265, Train Acc: 25.00% | Val Loss: 3.5271, Val Acc: 21.93%
# Epoch 16/150 | Train Loss: 3.2043, Train Acc: 28.12% | Val Loss: 3.4770, Val Acc: 22.91%
# Epoch 17/150 | Train Loss: 3.7153, Train Acc: 17.19% | Val Loss: 3.4659, Val Acc: 22.87%
# Epoch 18/150 | Train Loss: 3.5494, Train Acc: 21.88% | Val Loss: 3.4199, Val Acc: 24.30%
# Epoch 19/150 | Train Loss: 3.0748, Train Acc: 29.69% | Val Loss: 3.3845, Val Acc: 25.10%
# Epoch 20/150 | Train Loss: 3.6391, Train Acc: 20.31% | Val Loss: 3.3907, Val Acc: 25.45%
# Epoch 21/150 | Train Loss: 3.2183, Train Acc: 26.56% | Val Loss: 3.3172, Val Acc: 26.95%
# Epoch 22/150 | Train Loss: 3.3539, Train Acc: 28.12% | Val Loss: 3.3293, Val Acc: 26.17%
# Epoch 23/150 | Train Loss: 3.4670, Train Acc: 23.44% | Val Loss: 3.2581, Val Acc: 27.93%
# Epoch 24/150 | Train Loss: 3.1874, Train Acc: 28.12% | Val Loss: 3.2390, Val Acc: 28.35%
# Epoch 25/150 | Train Loss: 3.0498, Train Acc: 31.25% | Val Loss: 3.1950, Val Acc: 28.79%
# Epoch 26/150 | Train Loss: 3.0264, Train Acc: 31.25% | Val Loss: 3.2057, Val Acc: 29.89%
# Epoch 27/150 | Train Loss: 3.0800, Train Acc: 32.81% | Val Loss: 3.1831, Val Acc: 29.88%
# Epoch 28/150 | Train Loss: 2.8789, Train Acc: 42.19% | Val Loss: 3.1720, Val Acc: 30.53%
# Epoch 29/150 | Train Loss: 2.8768, Train Acc: 37.50% | Val Loss: 3.1121, Val Acc: 32.03%
# Epoch 30/150 | Train Loss: 2.7041, Train Acc: 42.19% | Val Loss: 3.1224, Val Acc: 31.32%
# Epoch 31/150 | Train Loss: 2.9042, Train Acc: 39.06% | Val Loss: 3.0972, Val Acc: 31.91%
# Epoch 32/150 | Train Loss: 2.7993, Train Acc: 40.62% | Val Loss: 3.0855, Val Acc: 33.00%
# Epoch 33/150 | Train Loss: 2.9840, Train Acc: 37.50% | Val Loss: 3.0450, Val Acc: 33.34%
# Epoch 34/150 | Train Loss: 2.6041, Train Acc: 45.31% | Val Loss: 3.0308, Val Acc: 33.74%
# Epoch 35/150 | Train Loss: 3.0339, Train Acc: 31.25% | Val Loss: 3.0458, Val Acc: 34.10%
# Epoch 36/150 | Train Loss: 2.9198, Train Acc: 35.94% | Val Loss: 3.0319, Val Acc: 33.99%
# Epoch 37/150 | Train Loss: 3.1644, Train Acc: 26.56% | Val Loss: 3.0204, Val Acc: 34.16%
# Epoch 38/150 | Train Loss: 2.9125, Train Acc: 39.06% | Val Loss: 2.9880, Val Acc: 35.38%
# Epoch 39/150 | Train Loss: 2.8145, Train Acc: 32.81% | Val Loss: 2.9810, Val Acc: 35.09%
# Epoch 40/150 | Train Loss: 3.0435, Train Acc: 34.38% | Val Loss: 2.9778, Val Acc: 35.37%
# Epoch 41/150 | Train Loss: 2.6404, Train Acc: 45.31% | Val Loss: 2.9611, Val Acc: 35.27%
# Epoch 42/150 | Train Loss: 2.9592, Train Acc: 34.38% | Val Loss: 2.9525, Val Acc: 35.92%
# Epoch 43/150 | Train Loss: 2.5639, Train Acc: 50.00% | Val Loss: 2.9247, Val Acc: 37.04%
# Epoch 44/150 | Train Loss: 2.8280, Train Acc: 37.50% | Val Loss: 2.9417, Val Acc: 36.80%
# Epoch 45/150 | Train Loss: 2.6497, Train Acc: 46.88% | Val Loss: 2.9112, Val Acc: 36.70%
# Epoch 46/150 | Train Loss: 2.7190, Train Acc: 35.94% | Val Loss: 2.9027, Val Acc: 37.53%
# Epoch 47/150 | Train Loss: 2.6026, Train Acc: 48.44% | Val Loss: 2.9046, Val Acc: 37.79%
# Epoch 48/150 | Train Loss: 2.6507, Train Acc: 42.19% | Val Loss: 2.8623, Val Acc: 38.66%
# Epoch 49/150 | Train Loss: 2.9259, Train Acc: 40.62% | Val Loss: 2.8845, Val Acc: 38.16%
# Epoch 50/150 | Train Loss: 2.6360, Train Acc: 37.50% | Val Loss: 2.8848, Val Acc: 38.05%
# Epoch 51/150 | Train Loss: 2.8805, Train Acc: 35.94% | Val Loss: 2.8859, Val Acc: 38.52%
# Epoch 52/150 | Train Loss: 2.5896, Train Acc: 40.62% | Val Loss: 2.8583, Val Acc: 38.76%
# Epoch 53/150 | Train Loss: 2.8454, Train Acc: 26.56% | Val Loss: 2.8539, Val Acc: 38.77%
# Epoch 54/150 | Train Loss: 2.3839, Train Acc: 59.38% | Val Loss: 2.8400, Val Acc: 38.89%
# Epoch 55/150 | Train Loss: 2.6102, Train Acc: 43.75% | Val Loss: 2.8441, Val Acc: 39.11%
# Epoch 56/150 | Train Loss: 2.4897, Train Acc: 43.75% | Val Loss: 2.8533, Val Acc: 39.05%
# Epoch 57/150 | Train Loss: 2.5407, Train Acc: 48.44% | Val Loss: 2.8336, Val Acc: 39.27%
# Epoch 58/150 | Train Loss: 2.7466, Train Acc: 43.75% | Val Loss: 2.8201, Val Acc: 39.59%
# Epoch 59/150 | Train Loss: 2.6627, Train Acc: 45.31% | Val Loss: 2.8153, Val Acc: 39.49%
# Epoch 60/150 | Train Loss: 2.5800, Train Acc: 48.44% | Val Loss: 2.8238, Val Acc: 40.08%
# Epoch 61/150 | Train Loss: 2.3091, Train Acc: 50.00% | Val Loss: 2.8038, Val Acc: 40.33%
# Epoch 62/150 | Train Loss: 2.7424, Train Acc: 31.25% | Val Loss: 2.8033, Val Acc: 40.13%
# Epoch 63/150 | Train Loss: 2.5429, Train Acc: 45.31% | Val Loss: 2.8069, Val Acc: 40.16%
# Epoch 64/150 | Train Loss: 2.5351, Train Acc: 42.19% | Val Loss: 2.7904, Val Acc: 41.10%
# Epoch 65/150 | Train Loss: 2.6462, Train Acc: 45.31% | Val Loss: 2.7837, Val Acc: 40.83%
# Epoch 66/150 | Train Loss: 2.5883, Train Acc: 46.88% | Val Loss: 2.7935, Val Acc: 40.32%
# Epoch 67/150 | Train Loss: 2.3966, Train Acc: 53.12% | Val Loss: 2.7770, Val Acc: 40.89%
# Epoch 68/150 | Train Loss: 2.3200, Train Acc: 56.25% | Val Loss: 2.7946, Val Acc: 40.65%
# Epoch 69/150 | Train Loss: 2.4187, Train Acc: 53.12% | Val Loss: 2.7714, Val Acc: 41.48%
# Epoch 70/150 | Train Loss: 2.9295, Train Acc: 37.50% | Val Loss: 2.7592, Val Acc: 41.59%
# Epoch 71/150 | Train Loss: 2.2548, Train Acc: 48.44% | Val Loss: 2.7530, Val Acc: 41.67%
# Epoch 72/150 | Train Loss: 2.3301, Train Acc: 54.69% | Val Loss: 2.7790, Val Acc: 41.92%
# Epoch 73/150 | Train Loss: 2.4932, Train Acc: 50.00% | Val Loss: 2.7532, Val Acc: 41.38%
# Epoch 74/150 | Train Loss: 2.2861, Train Acc: 59.38% | Val Loss: 2.7606, Val Acc: 41.57%
# Epoch 75/150 | Train Loss: 2.2989, Train Acc: 51.56% | Val Loss: 2.7534, Val Acc: 42.21%
# Epoch 76/150 | Train Loss: 2.2511, Train Acc: 57.81% | Val Loss: 2.7533, Val Acc: 41.89%
# Epoch 77/150 | Train Loss: 2.2637, Train Acc: 57.81% | Val Loss: 2.7898, Val Acc: 40.90%
# Epoch 78/150 | Train Loss: 2.1517, Train Acc: 60.94% | Val Loss: 2.7356, Val Acc: 42.64%
# Epoch 79/150 | Train Loss: 2.1603, Train Acc: 57.81% | Val Loss: 2.7252, Val Acc: 42.52%
# Epoch 80/150 | Train Loss: 1.9740, Train Acc: 67.19% | Val Loss: 2.7395, Val Acc: 42.67%
# Epoch 81/150 | Train Loss: 2.0541, Train Acc: 68.75% | Val Loss: 2.7146, Val Acc: 42.99%
# Epoch 82/150 | Train Loss: 2.3890, Train Acc: 45.31% | Val Loss: 2.7211, Val Acc: 42.80%
# Epoch 83/150 | Train Loss: 2.4451, Train Acc: 57.81% | Val Loss: 2.7261, Val Acc: 42.73%
# Epoch 84/150 | Train Loss: 2.3065, Train Acc: 50.00% | Val Loss: 2.7187, Val Acc: 43.13%
# Epoch 85/150 | Train Loss: 2.2712, Train Acc: 51.56% | Val Loss: 2.7196, Val Acc: 42.94%
# Epoch 86/150 | Train Loss: 2.2792, Train Acc: 60.94% | Val Loss: 2.7153, Val Acc: 43.09%
# Epoch 87/150 | Train Loss: 2.4492, Train Acc: 48.44% | Val Loss: 2.7177, Val Acc: 42.98%
# Epoch 88/150 | Train Loss: 2.6803, Train Acc: 43.75% | Val Loss: 2.7293, Val Acc: 42.68%
# Epoch 89/150 | Train Loss: 2.1220, Train Acc: 62.50% | Val Loss: 2.6937, Val Acc: 43.40%
# Epoch 90/150 | Train Loss: 2.3389, Train Acc: 48.44% | Val Loss: 2.7092, Val Acc: 43.67%
# Epoch 91/150 | Train Loss: 2.3473, Train Acc: 56.25% | Val Loss: 2.7215, Val Acc: 42.73%
# Epoch 92/150 | Train Loss: 2.4853, Train Acc: 43.75% | Val Loss: 2.7129, Val Acc: 43.38%
# Epoch 93/150 | Train Loss: 2.0798, Train Acc: 60.94% | Val Loss: 2.7164, Val Acc: 44.01%
# Epoch 94/150 | Train Loss: 2.1757, Train Acc: 57.81% | Val Loss: 2.6810, Val Acc: 43.96%
# Epoch 95/150 | Train Loss: 2.1501, Train Acc: 60.94% | Val Loss: 2.6835, Val Acc: 44.58%
# Epoch 96/150 | Train Loss: 2.2618, Train Acc: 56.25% | Val Loss: 2.7083, Val Acc: 44.06%
# Epoch 97/150 | Train Loss: 2.2840, Train Acc: 56.25% | Val Loss: 2.6845, Val Acc: 44.44%
# Epoch 98/150 | Train Loss: 2.0236, Train Acc: 60.94% | Val Loss: 2.6992, Val Acc: 43.92%
# Epoch 99/150 | Train Loss: 1.9540, Train Acc: 64.06% | Val Loss: 2.6895, Val Acc: 44.28%
# Epoch 100/150 | Train Loss: 2.0892, Train Acc: 59.38% | Val Loss: 2.6837, Val Acc: 44.20%
# Epoch 101/150 | Train Loss: 2.0986, Train Acc: 62.50% | Val Loss: 2.6807, Val Acc: 44.42%
# Epoch 102/150 | Train Loss: 2.1019, Train Acc: 54.69% | Val Loss: 2.6861, Val Acc: 44.22%
# Epoch 103/150 | Train Loss: 2.0731, Train Acc: 54.69% | Val Loss: 2.6806, Val Acc: 44.16%
# Epoch 104/150 | Train Loss: 2.2544, Train Acc: 57.81% | Val Loss: 2.6855, Val Acc: 45.00%
# Epoch 105/150 | Train Loss: 2.3844, Train Acc: 45.31% | Val Loss: 2.6876, Val Acc: 43.62%
# Epoch 106/150 | Train Loss: 2.0623, Train Acc: 64.06% | Val Loss: 2.6755, Val Acc: 44.05%
# Epoch 107/150 | Train Loss: 2.3230, Train Acc: 54.69% | Val Loss: 2.6851, Val Acc: 44.61%
# Epoch 108/150 | Train Loss: 2.3973, Train Acc: 53.12% | Val Loss: 2.7231, Val Acc: 43.39%
# Epoch 109/150 | Train Loss: 2.1375, Train Acc: 57.81% | Val Loss: 2.6787, Val Acc: 44.36%
# Epoch 110/150 | Train Loss: 1.9714, Train Acc: 59.38% | Val Loss: 2.6678, Val Acc: 45.04%
# Epoch 111/150 | Train Loss: 2.1668, Train Acc: 60.94% | Val Loss: 2.6776, Val Acc: 44.85%
# Epoch 112/150 | Train Loss: 1.9463, Train Acc: 64.06% | Val Loss: 2.6876, Val Acc: 44.39%
# Epoch 113/150 | Train Loss: 2.2123, Train Acc: 56.25% | Val Loss: 2.6708, Val Acc: 45.27%
# Epoch 114/150 | Train Loss: 2.4165, Train Acc: 48.44% | Val Loss: 2.6844, Val Acc: 44.30%
# Epoch 115/150 | Train Loss: 2.1361, Train Acc: 57.81% | Val Loss: 2.6761, Val Acc: 44.95%
# Epoch 116/150 | Train Loss: 2.2604, Train Acc: 50.00% | Val Loss: 2.7120, Val Acc: 43.67%
# Epoch 117/150 | Train Loss: 1.9639, Train Acc: 68.75% | Val Loss: 2.6813, Val Acc: 44.94%
# Epoch 118/150 | Train Loss: 1.9704, Train Acc: 57.81% | Val Loss: 2.6771, Val Acc: 44.99%
# Epoch 119/150 | Train Loss: 2.1329, Train Acc: 56.25% | Val Loss: 2.6879, Val Acc: 44.54%
# Epoch 120/150 | Train Loss: 1.9891, Train Acc: 65.62% | Val Loss: 2.6510, Val Acc: 45.44%
# Epoch 121/150 | Train Loss: 2.1236, Train Acc: 64.06% | Val Loss: 2.6997, Val Acc: 44.19%
# Epoch 122/150 | Train Loss: 1.9364, Train Acc: 62.50% | Val Loss: 2.6730, Val Acc: 44.99%
# Epoch 123/150 | Train Loss: 1.8801, Train Acc: 70.31% | Val Loss: 2.6654, Val Acc: 44.88%
# Epoch 124/150 | Train Loss: 2.1179, Train Acc: 60.94% | Val Loss: 2.6568, Val Acc: 45.29%
# Epoch 125/150 | Train Loss: 1.9585, Train Acc: 65.62% | Val Loss: 2.6598, Val Acc: 45.04%
# Epoch 126/150 | Train Loss: 2.0165, Train Acc: 57.81% | Val Loss: 2.6759, Val Acc: 45.21%
# Epoch 127/150 | Train Loss: 1.9501, Train Acc: 62.50% | Val Loss: 2.6761, Val Acc: 45.16%
# Epoch 128/150 | Train Loss: 1.6937, Train Acc: 70.31% | Val Loss: 2.6639, Val Acc: 45.18%
# Epoch 129/150 | Train Loss: 2.1059, Train Acc: 60.94% | Val Loss: 2.6840, Val Acc: 45.47%
# Epoch 130/150 | Train Loss: 2.0515, Train Acc: 64.06% | Val Loss: 2.6797, Val Acc: 45.14%
# Epoch 131/150 | Train Loss: 1.9671, Train Acc: 65.62% | Val Loss: 2.6715, Val Acc: 45.34%
# Epoch 132/150 | Train Loss: 1.9674, Train Acc: 64.06% | Val Loss: 2.6598, Val Acc: 44.72%
# Epoch 133/150 | Train Loss: 1.8707, Train Acc: 75.00% | Val Loss: 2.6692, Val Acc: 45.55%
# Epoch 134/150 | Train Loss: 1.9537, Train Acc: 62.50% | Val Loss: 2.6506, Val Acc: 45.67%
# Epoch 135/150 | Train Loss: 2.0727, Train Acc: 51.56% | Val Loss: 2.6524, Val Acc: 45.98%
# Epoch 136/150 | Train Loss: 2.0852, Train Acc: 67.19% | Val Loss: 2.6480, Val Acc: 45.92%
# Epoch 137/150 | Train Loss: 1.7497, Train Acc: 71.88% | Val Loss: 2.6819, Val Acc: 45.46%
# Epoch 138/150 | Train Loss: 1.9883, Train Acc: 60.94% | Val Loss: 2.7103, Val Acc: 44.85%
# Epoch 139/150 | Train Loss: 1.9680, Train Acc: 64.06% | Val Loss: 2.6594, Val Acc: 45.74%
# Epoch 140/150 | Train Loss: 2.1226, Train Acc: 64.06% | Val Loss: 2.6843, Val Acc: 45.18%
# Epoch 141/150 | Train Loss: 1.9619, Train Acc: 68.75% | Val Loss: 2.6868, Val Acc: 44.96%
# Epoch 142/150 | Train Loss: 1.6798, Train Acc: 76.56% | Val Loss: 2.6493, Val Acc: 45.73%
# Epoch 143/150 | Train Loss: 1.7825, Train Acc: 76.56% | Val Loss: 2.6761, Val Acc: 45.49%
# Epoch 144/150 | Train Loss: 2.1414, Train Acc: 50.00% | Val Loss: 2.6749, Val Acc: 45.89%
# Epoch 145/150 | Train Loss: 1.8989, Train Acc: 65.62% | Val Loss: 2.6619, Val Acc: 46.15%
# Epoch 146/150 | Train Loss: 2.1945, Train Acc: 59.38% | Val Loss: 2.6585, Val Acc: 46.18%
# Epoch 147/150 | Train Loss: 1.8616, Train Acc: 71.88% | Val Loss: 2.6912, Val Acc: 45.49%
# Epoch 148/150 | Train Loss: 1.9993, Train Acc: 64.06% | Val Loss: 2.6650, Val Acc: 45.70%
# Epoch 149/150 | Train Loss: 2.0999, Train Acc: 57.81% | Val Loss: 2.6785, Val Acc: 45.57%
# Epoch 150/150 | Train Loss: 2.0398, Train Acc: 60.94% | Val Loss: 2.6692, Val Acc: 46.36%
# Test Accuracy: 46.28%
# Running LocalSGD with 1 workers and 4 local steps
# Worker 0: Label Distribution - {0: 393, 1: 388, 2: 387, 3: 394, 4: 395, 5: 391, 6: 400, 7: 400, 8: 390, 9: 389, 10: 393, 11: 386, 12: 404, 13: 403, 14: 383, 15: 402, 16: 400, 17: 403, 18: 410, 19: 421, 20: 416, 21: 393, 22: 403, 23: 396, 24: 401, 25: 407, 26: 399, 27: 409, 28: 404, 29: 397, 30: 415, 31: 399, 32: 406, 33: 411, 34: 395, 35: 399, 36: 394, 37: 403, 38: 393, 39: 397, 40: 398, 41: 411, 42: 400, 43: 399, 44: 401, 45: 398, 46: 403, 47: 399, 48: 389, 49: 396, 50: 407, 51: 402, 52: 407, 53: 393, 54: 385, 55: 408, 56: 401, 57: 411, 58: 391, 59: 406, 60: 391, 61: 406, 62: 387, 63: 385, 64: 399, 65: 399, 66: 394, 67: 401, 68: 405, 69: 388, 70: 419, 71: 418, 72: 391, 73: 400, 74: 418, 75: 387, 76: 403, 77: 413, 78: 409, 79: 401, 80: 403, 81: 404, 82: 391, 83: 412, 84: 397, 85: 402, 86: 411, 87: 394, 88: 401, 89: 411, 90: 405, 91: 404, 92: 405, 93: 400, 94: 399, 95: 400, 96: 396, 97: 394, 98: 392, 99: 391}
# Epoch 1/150 | Train Loss: 4.3012, Train Acc: 4.69% | Val Loss: 4.3484, Val Acc: 4.27%
# Epoch 2/150 | Train Loss: 4.0191, Train Acc: 8.20% | Val Loss: 4.1417, Val Acc: 8.89%
# Epoch 3/150 | Train Loss: 3.8799, Train Acc: 15.62% | Val Loss: 3.9753, Val Acc: 11.35%
# Epoch 4/150 | Train Loss: 3.8351, Train Acc: 12.11% | Val Loss: 3.8859, Val Acc: 13.25%
# Epoch 5/150 | Train Loss: 3.8890, Train Acc: 12.50% | Val Loss: 3.7858, Val Acc: 16.17%
# Epoch 6/150 | Train Loss: 3.5308, Train Acc: 20.31% | Val Loss: 3.6819, Val Acc: 17.74%
# Epoch 7/150 | Train Loss: 3.5758, Train Acc: 21.88% | Val Loss: 3.6342, Val Acc: 18.75%
# Epoch 8/150 | Train Loss: 3.3837, Train Acc: 22.66% | Val Loss: 3.5389, Val Acc: 21.10%
# Epoch 9/150 | Train Loss: 3.4448, Train Acc: 25.78% | Val Loss: 3.4652, Val Acc: 22.97%
# Epoch 10/150 | Train Loss: 3.2926, Train Acc: 29.30% | Val Loss: 3.4629, Val Acc: 22.81%
# Epoch 11/150 | Train Loss: 3.3012, Train Acc: 26.95% | Val Loss: 3.3770, Val Acc: 24.94%
# Epoch 12/150 | Train Loss: 3.3212, Train Acc: 24.22% | Val Loss: 3.3148, Val Acc: 26.31%
# Epoch 13/150 | Train Loss: 3.1157, Train Acc: 35.55% | Val Loss: 3.2650, Val Acc: 27.42%
# Epoch 14/150 | Train Loss: 3.1220, Train Acc: 25.78% | Val Loss: 3.2313, Val Acc: 28.53%
# Epoch 15/150 | Train Loss: 3.1146, Train Acc: 26.56% | Val Loss: 3.2146, Val Acc: 28.57%
# Epoch 16/150 | Train Loss: 3.0737, Train Acc: 31.64% | Val Loss: 3.1814, Val Acc: 29.60%
# Epoch 17/150 | Train Loss: 2.9197, Train Acc: 35.94% | Val Loss: 3.1121, Val Acc: 30.76%
# Epoch 18/150 | Train Loss: 2.8574, Train Acc: 37.50% | Val Loss: 3.0992, Val Acc: 30.88%
# Epoch 19/150 | Train Loss: 2.9949, Train Acc: 31.25% | Val Loss: 3.1006, Val Acc: 31.92%
# Epoch 20/150 | Train Loss: 3.0031, Train Acc: 31.25% | Val Loss: 3.1089, Val Acc: 32.01%
# Epoch 21/150 | Train Loss: 2.8471, Train Acc: 36.72% | Val Loss: 3.0152, Val Acc: 34.40%
# Epoch 22/150 | Train Loss: 2.8434, Train Acc: 40.23% | Val Loss: 3.0477, Val Acc: 32.89%
# Epoch 23/150 | Train Loss: 2.7363, Train Acc: 44.14% | Val Loss: 2.9784, Val Acc: 34.98%
# Epoch 24/150 | Train Loss: 2.7027, Train Acc: 41.02% | Val Loss: 2.9747, Val Acc: 34.78%
# Epoch 25/150 | Train Loss: 2.7352, Train Acc: 42.97% | Val Loss: 2.9620, Val Acc: 35.09%
# Epoch 26/150 | Train Loss: 2.6000, Train Acc: 39.45% | Val Loss: 2.9651, Val Acc: 35.30%
# Epoch 27/150 | Train Loss: 2.6888, Train Acc: 42.19% | Val Loss: 2.9364, Val Acc: 35.83%
# Epoch 28/150 | Train Loss: 2.6087, Train Acc: 43.36% | Val Loss: 2.8896, Val Acc: 37.43%
# Epoch 29/150 | Train Loss: 2.7799, Train Acc: 39.45% | Val Loss: 2.9047, Val Acc: 37.25%
# Epoch 30/150 | Train Loss: 2.6798, Train Acc: 40.62% | Val Loss: 2.9204, Val Acc: 36.81%
# Epoch 31/150 | Train Loss: 2.7722, Train Acc: 39.84% | Val Loss: 2.8864, Val Acc: 37.84%
# Epoch 32/150 | Train Loss: 2.5695, Train Acc: 42.19% | Val Loss: 2.8410, Val Acc: 38.32%
# Epoch 33/150 | Train Loss: 2.6999, Train Acc: 41.41% | Val Loss: 2.8458, Val Acc: 39.19%
# Epoch 34/150 | Train Loss: 2.6007, Train Acc: 45.70% | Val Loss: 2.8858, Val Acc: 37.65%
# Epoch 35/150 | Train Loss: 2.5454, Train Acc: 44.14% | Val Loss: 2.7968, Val Acc: 39.98%
# Epoch 36/150 | Train Loss: 2.4898, Train Acc: 46.88% | Val Loss: 2.8873, Val Acc: 38.27%
# Epoch 37/150 | Train Loss: 2.5509, Train Acc: 47.66% | Val Loss: 2.7809, Val Acc: 40.70%
# Epoch 38/150 | Train Loss: 2.4077, Train Acc: 50.00% | Val Loss: 2.8083, Val Acc: 39.56%
# Epoch 39/150 | Train Loss: 2.5334, Train Acc: 44.92% | Val Loss: 2.8007, Val Acc: 40.53%
# Epoch 40/150 | Train Loss: 2.5904, Train Acc: 46.09% | Val Loss: 2.8077, Val Acc: 40.31%
# Epoch 41/150 | Train Loss: 2.6190, Train Acc: 44.53% | Val Loss: 2.7814, Val Acc: 40.48%
# Epoch 42/150 | Train Loss: 2.3291, Train Acc: 52.34% | Val Loss: 2.7381, Val Acc: 41.47%
# Epoch 43/150 | Train Loss: 2.3461, Train Acc: 50.39% | Val Loss: 2.7795, Val Acc: 41.06%
# Epoch 44/150 | Train Loss: 2.4446, Train Acc: 50.78% | Val Loss: 2.7978, Val Acc: 39.89%
# Epoch 45/150 | Train Loss: 2.3663, Train Acc: 49.22% | Val Loss: 2.7512, Val Acc: 41.61%
# Epoch 46/150 | Train Loss: 2.2283, Train Acc: 55.86% | Val Loss: 2.7406, Val Acc: 42.22%
# Epoch 47/150 | Train Loss: 2.2775, Train Acc: 51.17% | Val Loss: 2.8060, Val Acc: 40.02%
# Epoch 48/150 | Train Loss: 2.2184, Train Acc: 57.42% | Val Loss: 2.7679, Val Acc: 41.10%
# Epoch 49/150 | Train Loss: 2.3814, Train Acc: 50.00% | Val Loss: 2.7555, Val Acc: 41.64%
# Epoch 50/150 | Train Loss: 2.2756, Train Acc: 56.25% | Val Loss: 2.7139, Val Acc: 42.41%
# Epoch 51/150 | Train Loss: 2.2738, Train Acc: 52.34% | Val Loss: 2.8086, Val Acc: 40.74%
# Epoch 52/150 | Train Loss: 2.2999, Train Acc: 52.34% | Val Loss: 2.7505, Val Acc: 41.67%
# Epoch 53/150 | Train Loss: 2.2743, Train Acc: 55.08% | Val Loss: 2.7235, Val Acc: 43.12%
# Epoch 54/150 | Train Loss: 2.2687, Train Acc: 56.64% | Val Loss: 2.7020, Val Acc: 42.89%
# Epoch 55/150 | Train Loss: 2.1688, Train Acc: 58.59% | Val Loss: 2.7634, Val Acc: 41.29%
# Epoch 56/150 | Train Loss: 2.0726, Train Acc: 60.55% | Val Loss: 2.6724, Val Acc: 43.44%
# Epoch 57/150 | Train Loss: 2.2517, Train Acc: 51.17% | Val Loss: 2.7099, Val Acc: 43.03%
# Epoch 58/150 | Train Loss: 2.2036, Train Acc: 57.03% | Val Loss: 2.7601, Val Acc: 42.01%
# Epoch 59/150 | Train Loss: 2.2868, Train Acc: 53.91% | Val Loss: 2.7114, Val Acc: 43.18%
# Epoch 60/150 | Train Loss: 2.2515, Train Acc: 53.52% | Val Loss: 2.7961, Val Acc: 40.89%
# Epoch 61/150 | Train Loss: 2.2639, Train Acc: 58.59% | Val Loss: 2.7353, Val Acc: 42.03%
# Epoch 62/150 | Train Loss: 2.1374, Train Acc: 59.38% | Val Loss: 2.7519, Val Acc: 42.52%
# Epoch 63/150 | Train Loss: 2.0571, Train Acc: 64.45% | Val Loss: 2.6977, Val Acc: 43.67%
# Epoch 64/150 | Train Loss: 2.2066, Train Acc: 55.47% | Val Loss: 2.6947, Val Acc: 44.22%
# Epoch 65/150 | Train Loss: 2.1707, Train Acc: 57.81% | Val Loss: 2.6988, Val Acc: 44.11%
# Epoch 66/150 | Train Loss: 2.1357, Train Acc: 58.59% | Val Loss: 2.6917, Val Acc: 43.70%
# Epoch 67/150 | Train Loss: 1.9849, Train Acc: 62.50% | Val Loss: 2.7101, Val Acc: 44.49%
# Epoch 68/150 | Train Loss: 2.1148, Train Acc: 60.55% | Val Loss: 2.7014, Val Acc: 43.59%
# Epoch 69/150 | Train Loss: 2.1271, Train Acc: 60.55% | Val Loss: 2.7226, Val Acc: 42.57%
# Epoch 70/150 | Train Loss: 2.0129, Train Acc: 63.67% | Val Loss: 2.7121, Val Acc: 43.33%
# Epoch 71/150 | Train Loss: 2.1325, Train Acc: 62.50% | Val Loss: 2.7115, Val Acc: 43.81%
# Epoch 72/150 | Train Loss: 2.0880, Train Acc: 57.81% | Val Loss: 2.7256, Val Acc: 42.43%
# Epoch 73/150 | Train Loss: 1.9154, Train Acc: 65.23% | Val Loss: 2.7019, Val Acc: 43.66%
# Epoch 74/150 | Train Loss: 2.1407, Train Acc: 58.20% | Val Loss: 2.6879, Val Acc: 43.62%
# Epoch 75/150 | Train Loss: 2.0743, Train Acc: 61.33% | Val Loss: 2.6739, Val Acc: 44.80%
# Epoch 76/150 | Train Loss: 2.0745, Train Acc: 60.55% | Val Loss: 2.6890, Val Acc: 44.19%
# Epoch 77/150 | Train Loss: 2.0976, Train Acc: 57.03% | Val Loss: 2.6883, Val Acc: 44.39%
# Epoch 78/150 | Train Loss: 2.1399, Train Acc: 56.64% | Val Loss: 2.7323, Val Acc: 44.24%
# Epoch 79/150 | Train Loss: 2.0034, Train Acc: 67.58% | Val Loss: 2.6965, Val Acc: 44.44%
# Epoch 80/150 | Train Loss: 2.0559, Train Acc: 62.11% | Val Loss: 2.7309, Val Acc: 43.99%
# Epoch 81/150 | Train Loss: 2.0218, Train Acc: 65.23% | Val Loss: 2.7161, Val Acc: 43.94%
# Epoch 82/150 | Train Loss: 2.1649, Train Acc: 56.64% | Val Loss: 2.6793, Val Acc: 45.17%
# Epoch 83/150 | Train Loss: 1.9735, Train Acc: 65.23% | Val Loss: 2.7124, Val Acc: 44.07%
# Epoch 84/150 | Train Loss: 1.8471, Train Acc: 67.19% | Val Loss: 2.6949, Val Acc: 44.73%
# Epoch 85/150 | Train Loss: 2.0717, Train Acc: 62.11% | Val Loss: 2.6770, Val Acc: 44.94%
# Epoch 86/150 | Train Loss: 1.9579, Train Acc: 65.62% | Val Loss: 2.6556, Val Acc: 45.50%
